# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx

# %%
# Set headers
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# Yelp Business Search

# what type of business do you want to search
term = 'coffee'

#where do you want to perform this search
location = 'Astoria'

# what is your other parameter you want to search against
# measured in meters
radius = 5000

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "radius" : radius,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'coffee', 'location': 'Astoria', 'radius': 5000, 'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
if response.status_code == 200:
    return
else:
    print(response.status_code)
# Out:
#   File "<ipython-input-99-5e86b4e55be8>", line 2
#     return
#     ^
# SyntaxError: 'return' outside function

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
len(response.text)
# Out:
# 47712

# %%
response.text
# Out:
# '{"businesses": [{"id": "V0lISq2CcalvgAxAHMLwgA", "alias": "astoria-coffee-astoria", "name": "Astoria Coffee", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/siiZN0pt-2OLSjHDhchkLw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/astoria-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 293, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "icecream", "title": "Ice Cream & Frozen Yogurt"}, {"alias": "bakeries", "title": "Bakeries"}], "rating": 4.5, "coordinates": {"latitude": 40.7671240865304, "longitude": -73.9224924303384}, "transactions": [], "price": "$", "location": {"address1": "30-04 30th St", "address2": "", "address3": "", "city": "Astoria", "zip_code": "11102", "country": "US", "state": "NY", "display_address": ["30-04 30th St", "Astoria, NY 11102"]}, "phone": "+13476193915", "display_phone": "(347) 619-3915", "distance": 36.198604001785206}, {"id": "A7IV4pAQOL5M8X7StKS-4Q", "alias": "gossip-coffee-astoria-2", "name": "Gossip Coffee", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ys4idYhOxkvUejyxU9EFSg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/gossip-coffee-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 341, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "desserts", "title": "Desserts"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.0, "coordinates": {"latitude": 40.76436, "longitude": -73.9166}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "37-04 30th Ave", "address2": "", "address3": "", "city": "Astoria", "zip_code": "11103", "country": "US", "state": "NY", "display_address": ["37-04 30th Ave", "Astoria, NY 11103"]}, "phone": "+17184408792", "display_phone": "(718) 440-8792", "distance": 551.2241353497865}, {"id": "YGxBMFW_IXraXgPWbvnCqQ", "alias": "stellar-brews-queens-2", "name": "Stellar Brews", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/B2-cBPElJbkj5VKPBYVF3Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/stellar-brews-queens-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 6, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 40.7615005, "longitude": -73.9240539}, "transactions": ["pickup"], "location": {"address1": "32-13 Broadway Astoria", "address2": null, "address3": "", "city": "Queens", "zip_code": "11106", "country": "US", "state": "NY", "display_address": ["32-13 Broadway Astoria", "Queens, NY 11106"]}, "phone": "+16467839261", "display_phone": "(646) 783-9261", "distance": 614.2198937600384}, {"id": "gA0VbcoBLCiD2EpSC6vWeg", "alias": "partners-coffee-long-island-city", "name": "Partners Coffee", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/IFPTAgRmb3c6wePcDWd5VA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/partners-coffee-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 140, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "bakeries", "title": "Bakeries"}, {"alias": "internetcafe", "title": "Internet Cafes"}], "rating": 4.5, "coordinates": {"latitude": 40.74769, "longitude": -73.9416}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "26-25 Jackson Ave", "address2": "", "address3": null, "city": "Long Island City", "zip_code": "11101", "country": "US", "state": "NY", "display_address": ["26-25 Jackson Ave", "Long Island City, NY 11101"]}, "phone": "+13475310477", "display_phone": "(347) 531-0477", "di ...

# %%
len(json.loads(response.text))
# Out:
# 3

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'V0lISq2CcalvgAxAHMLwgA',
#    'alias': 'astoria-coffee-astoria',
#    'name': 'Astoria Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/siiZN0pt-2OLSjHDhchkLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 293,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7671240865304,
#     'longitude': -73.9224924303384},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '30-04 30th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-04 30th St', 'Astoria, NY 11102']},
#    'phone': '+13476193915',
#    'display_phone': '(347) 619-3915',
#    'distance': 36.198604001785206},
#   {'id': 'A7IV4pAQOL5M8X7StKS-4Q',
#    'alias': 'gossip-coffee-astoria-2',
#    'name': 'Gossip Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ys4idYhOxkvUejyxU9EFSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gossip-coffee-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 341,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76436, 'longitude': -73.9166},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-04 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-04 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17184408792',
#    'display_phone': '(718) 440-8792',
#    'distance': 551.2241353497865},
#   {'id': 'YGxBMFW_IXraXgPWbvnCqQ',
#    'alias': 'stellar-brews-queens-2',
#    'name': 'Stellar Brews',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B2-cBPElJbkj5VKPBYVF3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stellar-brews-queens-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7615005, 'longitude': -73.9240539},
#    'transactions': ['pickup'],
#    'location': {'address1': '32-13 Broadway Astoria',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-13 Broadway Astoria', 'Queens, NY 11106']},
#    'phone': '+16467839261',
#    'display_phone': '(646) 783-9261',
#    'distance': 614.2198937600384},
#   {'id': 'gA0VbcoBLCiD2EpSC6vWeg',
#    'alias': 'partners-coffee-long-island-city',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IFPTAgRmb3c6wePcDWd5VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 140,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'internetcafe', 'title': 'Internet Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74769, 'longitude': -73.9416},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26-25 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-25 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+13475310477',
#    'display_phone': '(347) 531-0477',
#    'distance': 2692.5164229157713},
#   {'id': 'LdD70vbg64ufRoMOw1Kjuw',
#    'alias': 'mighty-oak-roasters-astoria',
#    'name': 'Mighty Oak Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gyk4yTqR5qs-Ql1ylvzasw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mighty-oak-roasters-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 46,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77358, 'longitude': -73.91675},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '28-01 24th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-01 24th Ave', 'Astoria, NY 11102']},
#    'phone': '+17187779663',
#    'display_phone': '(718) 777-9663',
#    'distance': 865.6108311280316},
#   {'id': 'fJOE_ZHGB9u3eb2QqFhNTA',
#    'alias': 'kinship-coffee-astoria',
#    'name': 'Kinship Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AJk9tczQ6l2rHwde4n_BPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinship-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 112,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7587054, 'longitude': -73.9195167},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32-14 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-14 Steinway St', 'Astoria, NY 11103']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 937.4969304426353},
#   {'id': 'JagdE5Vv84kTkHga4Th2EA',
#    'alias': 'sip-a-cup-long-island-city',
#    'name': 'Sip A Cup',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V9FQy1mVM6Yd4nKd0Hh6ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sip-a-cup-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 30,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7686472, 'longitude': -73.9248045},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2517 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2517 30th Ave', 'Long Island City, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 253.61529979797317},
#   {'id': '20ugkDBhcN3-FgsPztOuxg',
#    'alias': 'sweet-scene-astoria',
#    'name': 'Sweet Scene',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t-8dwLsg6B14Z1KOkoL8cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-scene-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 59,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7579167577173,
#     'longitude': -73.9235702127254},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '35-13 34th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 34th Ave', 'Astoria, NY 11106']},
#    'phone': '+19178327443',
#    'display_phone': '(917) 832-7443',
#    'distance': 1004.3359168333825},
#   {'id': 'ppTV9F9QCOsmsbC3UBLiEw',
#    'alias': 'park-coffee-new-york',
#    'name': 'Park Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y11zPLPLzrPR2nTAmpwFuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-coffee-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77632, 'longitude': -73.91518},
#    'transactions': [],
#    'location': {'address1': '26-17 23rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-17 23rd Ave', 'New York, NY 11105']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1204.2774146991496},
#   {'id': 'LNV-uST6FKzn7XN-QtFFsQ',
#    'alias': 'coffee-plus-cake-new-york-2',
#    'name': 'Coffee Plus Cake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rl1WsTIM9hyVSv_3-TG4Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-plus-cake-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77139, 'longitude': -73.9222},
#    'transactions': [],
#    'location': {'address1': '25-11 Astoria Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-11 Astoria Blvd', 'New York, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 501.2493371697826},
#   {'id': 'mxsbNvFTy6_4nSq-UWcYkw',
#    'alias': '787-coffee-new-york-3',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BN_v3lBNe1Uf6UmpMTgA6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77435, 'longitude': -73.95557},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '228 E 80th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 E 80th St', 'New York, NY 10075']},
#    'phone': '+16468500234',
#    'display_phone': '(646) 850-0234',
#    'distance': 2933.528835540639},
#   {'id': 'ODgsRl7zg6cwNSQLE0SGIQ',
#    'alias': 'madame-sousou-cafe-astoria',
#    'name': 'Madame Sousou Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/trzsJ8XiKX93KZmDJYZPBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madame-sousou-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 153,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7633468, 'longitude': -73.9220508},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '31-05 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-05 33rd St', 'Astoria, NY 11106']},
#    'phone': '+17187106577',
#    'display_phone': '(718) 710-6577',
#    'distance': 394.035169195003},
#   {'id': 'sEb8Qfx4bRKkM4fgFBRJzQ',
#    'alias': 'regalia-roasting-collective-long-island-city',
#    'name': 'Regalia Roasting Collective',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Yjaywic09bKH9JNvKP8Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regalia-roasting-collective-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 5,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7547844512305,
#     'longitude': -73.9371085166931},
#    'transactions': [],
#    'location': {'address1': '3902 Crescent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3902 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+19178057442',
#    'display_phone': '(917) 805-7442',
#    'distance': 1840.9674107447963},
#   {'id': 'QjMeljDv9TH5BWzsDfwLVw',
#    'alias': 'flor-de-azalea-cafe-astoria',
#    'name': 'Flor de Azalea Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FF1fS5ZDhV7Ea6vQaVpTDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flor-de-azalea-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 47,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7650992, 'longitude': -73.9394082},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '902 34th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['902 34th Ave', 'Astoria, NY 11106']},
#    'phone': '+17187770523',
#    'display_phone': '(718) 777-0523',
#    'distance': 1463.2018595225059},
#   {'id': 'R_BIm9sV7iH9jFQqYLQ5tg',
#    'alias': 'cascara-coffee-and-tea-queens-2',
#    'name': 'Cascara Coffee And Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lD6VfKO4NQyQ7Rph9SGdQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cascara-coffee-and-tea-queens-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7671716, 'longitude': -73.9202752},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '31-19 Newtown Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-19 Newtown Ave', 'Queens, NY 11102']},
#    'phone': '+17186068606',
#    'display_phone': '(718) 606-8606',
#    'distance': 169.0747228734464},
#   {'id': 'tM3Zj_Cp3A8yKKywPKieIw',
#    'alias': 'menú-astoria',
#    'name': 'Menú',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4C6zAjz0Wv6j8SlmJDaM5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/men%C3%BA-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 99,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7576356, 'longitude': -73.9269118},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '34-56 33rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-56 33rd St', 'Astoria, NY 11106']},
#    'phone': '+17186852566',
#    'display_phone': '(718) 685-2566',
#    'distance': 1102.9164792183465},
#   {'id': '2Pvm8P4tXH_kd1nSSe4Z0A',
#    'alias': 'dear-han-cafe-woodside',
#    'name': 'Dear Han Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wJc7auCPJs5ysKEQMUrYaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dear-han-cafe-woodside?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7452451696603,
#     'longitude': -73.9054226808178},
#    'transactions': [],
#    'location': {'address1': '59-02 Woodside Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['59-02 Woodside Ave', 'Woodside, NY 11377']},
#    'phone': '+17184249838',
#    'display_phone': '(718) 424-9838',
#    'distance': 2790.6775766002997},
#   {'id': 'vkTIiY71TC4_xUw4k7KdBA',
#    'alias': 'under-pressure-espresso-bar-astoria',
#    'name': 'Under Pressure Espresso Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ExGz3gtX9u2DU7nAfAgX9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/under-pressure-espresso-bar-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.764777, 'longitude': -73.92353},
#    'transactions': [],
#    'location': {'address1': '30-92 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-92 31st St', 'Astoria, NY 11102']},
#    'phone': '+17184339380',
#    'display_phone': '(718) 433-9380',
#    'distance': 256.9324877327024},
#   {'id': '2uS1f2hNHPzHPOLUdxrVHA',
#    'alias': 'kinship-coffee-astoria-3',
#    'name': 'Kinship Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DmFaKAqP28nSoUWTTqvjIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinship-coffee-astoria-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 198,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7634513207248,
#     'longitude': -73.9151231902811},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '30-05 Steinway St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-05 Steinway St', 'Astoria, NY 11103']},
#    'phone': '+16464687149',
#    'display_phone': '(646) 468-7149',
#    'distance': 707.7060722085931},
#   {'id': 'FSQsMolZ5SONv0I1trhvwA',
#    'alias': 'moa-coffee-astoria',
#    'name': 'Moa Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvbEIz9iI_iOvDMnkZJ-WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moa-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76243, 'longitude': -73.91258},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '43-04 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-04 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19293280043',
#    'display_phone': '(929) 328-0043',
#    'distance': 946.8500306031873},
#   {'id': 'bqf-UHIqzbSdrr7m1CsaVw',
#    'alias': 'crossbar-café-queens',
#    'name': 'Crossbar Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i6qcyxx-iWcp0hd9gLqnUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crossbar-caf%C3%A9-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7561262, 'longitude': -73.922199},
#    'transactions': [],
#    'location': {'address1': '34-23 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-23 38th St', 'Queens, NY 11101']},
#    'phone': '+16464179646',
#    'display_phone': '(646) 417-9646',
#    'distance': 1176.759350234871},
#   {'id': 'L9SKVe8qIvL_ZUrWwitdfQ',
#    'alias': 'château-le-woof-astoria-2',
#    'name': 'Château le Woof',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2QiU7ljwmtq_1sNClxlXzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A2teau-le-woof-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 97,
#    'categories': [{'alias': 'petstore', 'title': 'Pet Stores'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7691527, 'longitude': -73.9353705},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31-01 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-01 Vernon Blvd', 'Astoria, NY 11106']},
#    'phone': '+17186269663',
#    'display_phone': '(718) 626-9663',
#    'distance': 1137.7308673415139},
#   {'id': 'iuveiLDb5UMgR__GDa6_Ow',
#    'alias': 'balancero-astoria',
#    'name': 'Balancero',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Tttv3T4S3EOa21yvzk24Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balancero-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.762306, 'longitude': -73.918382},
#    'transactions': [],
#    'location': {'address1': '30-95 37th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-95 37th St', 'Astoria, NY 11103']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 602.3418722528346},
#   {'id': 'zHR6xvSiqX9UqAAaTsAoNw',
#    'alias': 'sweetleaf-coffee-long-island-city-2',
#    'name': 'Sweetleaf Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/msQnyfMPB2O4cVWhlvqyYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetleaf-coffee-long-island-city-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748429, 'longitude': -73.9383244},
#    'transactions': [],
#    'location': {'address1': '28-10 Jackson Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-10 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183618000',
#    'display_phone': '(718) 361-8000',
#    'distance': 2475.620547405862},
#   {'id': 'wlZUabctW1qOQbg-OCPhzA',
#    'alias': 'ok-cafe-astoria',
#    'name': 'OK Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JvLxloszSKdti8XK4ZmfVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ok-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 167,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7752143591642,
#     'longitude': -73.9098901301622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '22-04 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22-04 33rd St', 'Astoria, NY 11105']},
#    'phone': '+17184408789',
#    'display_phone': '(718) 440-8789',
#    'distance': 1389.778499310231},
#   {'id': 'fUuy7SqkGJPWpF5NwDklFA',
#    'alias': 'astoria-provisions-long-island-city',
#    'name': 'Astoria Provisions',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rAtxif9BmNh_eO8QVp2oCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-provisions-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 155,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722612331431,
#     'longitude': -73.9291319623589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '12-23 Astoria Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12-23 Astoria Blvd', 'Long Island City, NY 11102']},
#    'phone': '+19173964002',
#    'display_phone': '(917) 396-4002',
#    'distance': 835.5232619184637},
#   {'id': 'vrrJiOKEfCKnSOnEgagW7Q',
#    'alias': 'coffee-and-green-queens',
#    'name': 'Coffee & Green',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UiZOqq5v7bgdSW2KQJukRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-and-green-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7596849, 'longitude': -73.9367117},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2106 36th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2106 36th Ave', 'Queens, NY 11106']},
#    'phone': '+17186068414',
#    'display_phone': '(718) 606-8414',
#    'distance': 1460.6049862067885},
#   {'id': 'YI49ybEJNLBbzwl5Qx2AMg',
#    'alias': 'cafe-boulis-astoria',
#    'name': 'Cafe Boulis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mjwPnvpliSE0c9fYICM8tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-boulis-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 190,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7646102445833,
#     'longitude': -73.9236790957008},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '30-15 31st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-15 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17188061014',
#    'display_phone': '(718) 806-1014',
#    'distance': 282.49418880750454},
#   {'id': 'lm6AchFt32BqTf3OoQBBPw',
#    'alias': 'sonbobs-astoria',
#    'name': 'Sonbobs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lKAuwE8vvTmCtEtP8GyYPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sonbobs-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7673603, 'longitude': -73.917382},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '34-15 28th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-15 28th Ave', 'Astoria, NY 11103']},
#    'phone': '+13475272217',
#    'display_phone': '(347) 527-2217',
#    'distance': 429.4574593389625},
#   {'id': 'W5XLAjpyO3WscCEhARpyrQ',
#    'alias': 'biskoti-bakery-cafe-astoria',
#    'name': 'Biskoti Bakery Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wB7xkA2FOWJ6S510HfGKUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biskoti-bakery-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76413, 'longitude': -73.91606},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-20 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-20 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19292960180',
#    'display_phone': '(929) 296-0180',
#    'distance': 600.141817182123},
#   {'id': '6moXprIoZQnL82vAiCTY1Q',
#    'alias': 'coffee-pot-astoria',
#    'name': 'Coffee Pot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YyFyFnAQO5T9BFg9YwcfoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-pot-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77534, 'longitude': -73.91378},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2819 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2819 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17187261274',
#    'display_phone': '(718) 726-1274',
#    'distance': 1173.592999617699},
#   {'id': 'bvuPipiMPe5FURKZh06Zxg',
#    'alias': 'tea-and-milk-astoria',
#    'name': 'Tea and Milk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b3FHw1yZ7K5lcXp-J13Zww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-milk-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 403,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75904, 'longitude': -73.92631},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '32-02 34th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-02 34th Ave', 'Astoria, NY 11106']},
#    'phone': '+13479212056',
#    'display_phone': '(347) 921-2056',
#    'distance': 933.3178372150321},
#   {'id': 'i6tJsImlASP0mZWH3vf9uQ',
#    'alias': 'sweet-habit-astoria',
#    'name': 'Sweet Habit',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F_5nPLsO6cqBeVE2IamQpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-habit-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75707, 'longitude': -73.91439},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4511 Broadway',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4511 Broadway', 'Fl 1', 'Astoria, NY 11103']},
#    'phone': '+13475272602',
#    'display_phone': '(347) 527-2602',
#    'distance': 1273.0365322403984},
#   {'id': 'owvn3TwI2oweLWh4D7strA',
#    'alias': 'comfortland-astoria-2',
#    'name': 'Comfortland',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8M3uq_v8ug9JCQgHO1oA9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comfortland-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 141,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763751576777,
#     'longitude': -73.9145824245542},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40-09 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-09 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+16314579815',
#    'display_phone': '(631) 457-9815',
#    'distance': 729.18226925672},
#   {'id': 't01jp2WFJvAWh_TGk7Aguw',
#    'alias': 'infinitea-ny-astoria',
#    'name': 'INFINITEA NY',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qmik9UONstebmLyjX6GRAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/infinitea-ny-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 110,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77185, 'longitude': -73.9237799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2309 Astoria Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2309 Astoria Blvd', 'Astoria, NY 11102']},
#    'phone': '+17187770698',
#    'display_phone': '(718) 777-0698',
#    'distance': 561.1703055390101},
#   {'id': '_DPasRlhN-P3Y1b24NWzMA',
#    'alias': 'kinship-coffee-astoria-5',
#    'name': 'Kinship Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/o8q3cAJuM6K5qD08mC5Qmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinship-coffee-astoria-5?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 11,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7620306, 'longitude': -73.9258523},
#    'transactions': [],
#    'location': {'address1': '30-10 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-10 Broadway', 'Astoria, NY 11106']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 621.8261073428001},
#   {'id': '7ov7U0U9UbzRjlLw7wL9bg',
#    'alias': 'the-teapsy-new-york-astoria',
#    'name': 'The Teapsy New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ikZd8vrLqUMz756M8tw1Xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-teapsy-new-york-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 142,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7658014094971,
#     'longitude': -73.9191635864046},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '33-17 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-17 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19293280090',
#    'display_phone': '(929) 328-0090',
#    'distance': 282.51173464297125},
#   {'id': 'R8OGE7C4u_22y8KL8zdHyQ',
#    'alias': 'the-mill-coffee-company-long-island-city',
#    'name': 'The Mill Coffee Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3fbZn4t8d3chrXmTJNoHUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mill-coffee-company-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7483347, 'longitude': -73.9495972},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '44-61 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44-61 11th St', 'Long Island City, NY 11101']},
#    'phone': '+17188436455',
#    'display_phone': '(718) 843-6455',
#    'distance': 3095.6810153370984},
#   {'id': 'iZ_OF8GKvBZh_fPIpwdGKw',
#    'alias': 'astoria-cafe-queens',
#    'name': 'Astoria Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mDD9ayxHy7A_oB8JJ1Hs5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-cafe-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77217, 'longitude': -73.92075},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2608 Hoyt Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2608 Hoyt Ave S', 'Queens, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 599.7193629816181},
#   {'id': 'asW_ljefQQam9zjc9ZQaMw',
#    'alias': 'oslo-coffee-roasters-new-york',
#    'name': 'Oslo Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xALfil8scd3ylUlJ50h_kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oslo-coffee-roasters-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 247,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76914, 'longitude': -73.95372},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '422 E 75th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['422 E 75th St', 'New York, NY 10021']},
#    'phone': '+17187820332',
#    'display_phone': '(718) 782-0332',
#    'distance': 2667.047334910252},
#   {'id': 'zPdIeG11UZ6TkUtBeVYkmQ',
#    'alias': 'la-barista-queens',
#    'name': 'La Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/idcgxbyRCuI1ek2H-rBV_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-barista-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.767541, 'longitude': -73.923342},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2910 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2910 30th Ave', 'Queens, NY 11102']},
#    'phone': '+19294621111',
#    'display_phone': '(929) 462-1111',
#    'distance': 121.59639970281188},
#   {'id': 'Rc9_uzaTwqFTG1LGlbTPxQ',
#    'alias': 'new-york-city-bagel-and-coffee-house-astoria-2',
#    'name': 'New York City Bagel & Coffee House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8ejO2BbnrFfHbRDFavYmcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-city-bagel-and-coffee-house-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 239,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7589283752034,
#     'longitude': -73.9186164388547},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '40-05 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-05 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17187289511',
#    'display_phone': '(718) 728-9511',
#    'distance': 935.0685542769104},
#   {'id': 'mIDV-IEfeZsQtVW1BUHXLA',
#    'alias': 'indie-long-island-city',
#    'name': 'Indie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wwxPYVC7_6Ier6JB47ch8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indie-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 135,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748884, 'longitude': -73.942401},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '43-10 Crescent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-10 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+17184826954',
#    'display_phone': '(718) 482-6954',
#    'distance': 2627.6362635679043},
#   {'id': 'LjmfjBHC-dQ5ld3qq9moXw',
#    'alias': 'variety-coffee-roasters-new-york-4',
#    'name': 'Variety Coffee Roasters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jKMJicgkbGAJpjriaKn4NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/variety-coffee-roasters-new-york-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779005, 'longitude': -73.95569},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1269 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1269 Lexington Ave', 'New York, NY 10028']},
#    'phone': '+12122892104',
#    'display_phone': '(212) 289-2104',
#    'distance': 3125.7699938135524},
#   {'id': 'ydFXOSGLl-pqLXccd6qaJQ',
#    'alias': 'queens-room-astoria-3',
#    'name': "Queen's Room",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Y1IOBOh_alaAYhL5TBC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-room-astoria-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 132,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7741316, 'longitude': -73.9082624},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3602 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3602 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+13479873994',
#    'display_phone': '(347) 987-3994',
#    'distance': 1423.1279595334672},
#   {'id': 'euO-c5OpErE3UJCAliC4Bw',
#    'alias': 'mellow-yellow-new-york-3',
#    'name': 'Mellow Yellow',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gDbYdKYGj8oAetrJ2jk8Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mellow-yellow-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 280,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77929, 'longitude': -73.94785},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1729 1st Av',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1729 1st Av', 'New York, NY 10128']},
#    'phone': '+12127227220',
#    'display_phone': '(212) 722-7220',
#    'distance': 2567.232038123589},
#   {'id': 'CXgpu7gm6ofb_ldC_q9GmA',
#    'alias': 'bb-cafe-long-island-city',
#    'name': 'BB Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qYP66cSpxWypAKve3SjD2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bb-cafe-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7530215861517,
#     'longitude': -73.9332820102572},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3007 39th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3007 39th Ave', 'Long Island City, NY 11101']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1802.649468404453},
#   {'id': 'jeu3yDGlvY-yInrO3e2mFQ',
#    'alias': 'standard-cafe-new-york',
#    'name': 'Standard Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2I05wHNx6Inm_sYeJfv0uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/standard-cafe-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75194, 'longitude': -73.925413},
#    'transactions': [],
#    'location': {'address1': '37-18 Northern Blvd',
#     'address2': 'Ste 106',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-18 Northern Blvd',
#      'Ste 106',
#      'New York, NY 11101']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1684.170142296687},
#   {'id': 'bIhtPWm8YvcExO1ye9L0HA',
#    'alias': 'coffeed-queens-4',
#    'name': 'Coffeed',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iFzN_viGtTOvVWrrnktDXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffeed-queens-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.768133, 'longitude': -73.924766},
#    'transactions': [],
#    'location': {'address1': '25-10 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-10 30th Ave', 'Queens, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 281.73310900358445},
#   {'id': 'MjkCDpn7zYYXj2bBP3Oadw',
#    'alias': 'black-star-bakery-and-cafe-new-york-2',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-8szCAw1IKcyj3B78y1XpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7749269639842,
#     'longitude': -73.948163241148},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1597 York Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1597 York Ave', 'New York, NY 10028']},
#    'phone': '+16467264546',
#    'display_phone': '(646) 726-4546',
#    'distance': 2362.3829003150204}],
#  'total': 1500,
#  'region': {'center': {'longitude': -73.92219543457031,
#    'latitude': 40.76688875374591}}}

# %%
len(response.json())
# Out:
# 3

# %%
response.json()
# Out:
# {'businesses': [{'id': 'V0lISq2CcalvgAxAHMLwgA',
#    'alias': 'astoria-coffee-astoria',
#    'name': 'Astoria Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/siiZN0pt-2OLSjHDhchkLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 293,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7671240865304,
#     'longitude': -73.9224924303384},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '30-04 30th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-04 30th St', 'Astoria, NY 11102']},
#    'phone': '+13476193915',
#    'display_phone': '(347) 619-3915',
#    'distance': 36.198604001785206},
#   {'id': 'A7IV4pAQOL5M8X7StKS-4Q',
#    'alias': 'gossip-coffee-astoria-2',
#    'name': 'Gossip Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ys4idYhOxkvUejyxU9EFSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gossip-coffee-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 341,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76436, 'longitude': -73.9166},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-04 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-04 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17184408792',
#    'display_phone': '(718) 440-8792',
#    'distance': 551.2241353497865},
#   {'id': 'YGxBMFW_IXraXgPWbvnCqQ',
#    'alias': 'stellar-brews-queens-2',
#    'name': 'Stellar Brews',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B2-cBPElJbkj5VKPBYVF3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stellar-brews-queens-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7615005, 'longitude': -73.9240539},
#    'transactions': ['pickup'],
#    'location': {'address1': '32-13 Broadway Astoria',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-13 Broadway Astoria', 'Queens, NY 11106']},
#    'phone': '+16467839261',
#    'display_phone': '(646) 783-9261',
#    'distance': 614.2198937600384},
#   {'id': 'gA0VbcoBLCiD2EpSC6vWeg',
#    'alias': 'partners-coffee-long-island-city',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IFPTAgRmb3c6wePcDWd5VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 140,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'internetcafe', 'title': 'Internet Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74769, 'longitude': -73.9416},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26-25 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-25 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+13475310477',
#    'display_phone': '(347) 531-0477',
#    'distance': 2692.5164229157713},
#   {'id': 'LdD70vbg64ufRoMOw1Kjuw',
#    'alias': 'mighty-oak-roasters-astoria',
#    'name': 'Mighty Oak Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gyk4yTqR5qs-Ql1ylvzasw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mighty-oak-roasters-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 46,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77358, 'longitude': -73.91675},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '28-01 24th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-01 24th Ave', 'Astoria, NY 11102']},
#    'phone': '+17187779663',
#    'display_phone': '(718) 777-9663',
#    'distance': 865.6108311280316},
#   {'id': 'fJOE_ZHGB9u3eb2QqFhNTA',
#    'alias': 'kinship-coffee-astoria',
#    'name': 'Kinship Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AJk9tczQ6l2rHwde4n_BPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinship-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 112,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7587054, 'longitude': -73.9195167},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32-14 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-14 Steinway St', 'Astoria, NY 11103']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 937.4969304426353},
#   {'id': 'JagdE5Vv84kTkHga4Th2EA',
#    'alias': 'sip-a-cup-long-island-city',
#    'name': 'Sip A Cup',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V9FQy1mVM6Yd4nKd0Hh6ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sip-a-cup-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 30,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7686472, 'longitude': -73.9248045},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2517 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2517 30th Ave', 'Long Island City, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 253.61529979797317},
#   {'id': '20ugkDBhcN3-FgsPztOuxg',
#    'alias': 'sweet-scene-astoria',
#    'name': 'Sweet Scene',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t-8dwLsg6B14Z1KOkoL8cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-scene-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 59,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7579167577173,
#     'longitude': -73.9235702127254},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '35-13 34th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 34th Ave', 'Astoria, NY 11106']},
#    'phone': '+19178327443',
#    'display_phone': '(917) 832-7443',
#    'distance': 1004.3359168333825},
#   {'id': 'ppTV9F9QCOsmsbC3UBLiEw',
#    'alias': 'park-coffee-new-york',
#    'name': 'Park Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y11zPLPLzrPR2nTAmpwFuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-coffee-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77632, 'longitude': -73.91518},
#    'transactions': [],
#    'location': {'address1': '26-17 23rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-17 23rd Ave', 'New York, NY 11105']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1204.2774146991496},
#   {'id': 'LNV-uST6FKzn7XN-QtFFsQ',
#    'alias': 'coffee-plus-cake-new-york-2',
#    'name': 'Coffee Plus Cake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rl1WsTIM9hyVSv_3-TG4Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-plus-cake-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77139, 'longitude': -73.9222},
#    'transactions': [],
#    'location': {'address1': '25-11 Astoria Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-11 Astoria Blvd', 'New York, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 501.2493371697826},
#   {'id': 'mxsbNvFTy6_4nSq-UWcYkw',
#    'alias': '787-coffee-new-york-3',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BN_v3lBNe1Uf6UmpMTgA6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77435, 'longitude': -73.95557},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '228 E 80th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 E 80th St', 'New York, NY 10075']},
#    'phone': '+16468500234',
#    'display_phone': '(646) 850-0234',
#    'distance': 2933.528835540639},
#   {'id': 'ODgsRl7zg6cwNSQLE0SGIQ',
#    'alias': 'madame-sousou-cafe-astoria',
#    'name': 'Madame Sousou Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/trzsJ8XiKX93KZmDJYZPBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madame-sousou-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 153,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7633468, 'longitude': -73.9220508},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '31-05 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-05 33rd St', 'Astoria, NY 11106']},
#    'phone': '+17187106577',
#    'display_phone': '(718) 710-6577',
#    'distance': 394.035169195003},
#   {'id': 'sEb8Qfx4bRKkM4fgFBRJzQ',
#    'alias': 'regalia-roasting-collective-long-island-city',
#    'name': 'Regalia Roasting Collective',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Yjaywic09bKH9JNvKP8Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regalia-roasting-collective-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 5,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7547844512305,
#     'longitude': -73.9371085166931},
#    'transactions': [],
#    'location': {'address1': '3902 Crescent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3902 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+19178057442',
#    'display_phone': '(917) 805-7442',
#    'distance': 1840.9674107447963},
#   {'id': 'QjMeljDv9TH5BWzsDfwLVw',
#    'alias': 'flor-de-azalea-cafe-astoria',
#    'name': 'Flor de Azalea Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FF1fS5ZDhV7Ea6vQaVpTDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flor-de-azalea-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 47,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7650992, 'longitude': -73.9394082},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '902 34th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['902 34th Ave', 'Astoria, NY 11106']},
#    'phone': '+17187770523',
#    'display_phone': '(718) 777-0523',
#    'distance': 1463.2018595225059},
#   {'id': 'R_BIm9sV7iH9jFQqYLQ5tg',
#    'alias': 'cascara-coffee-and-tea-queens-2',
#    'name': 'Cascara Coffee And Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lD6VfKO4NQyQ7Rph9SGdQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cascara-coffee-and-tea-queens-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7671716, 'longitude': -73.9202752},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '31-19 Newtown Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-19 Newtown Ave', 'Queens, NY 11102']},
#    'phone': '+17186068606',
#    'display_phone': '(718) 606-8606',
#    'distance': 169.0747228734464},
#   {'id': 'tM3Zj_Cp3A8yKKywPKieIw',
#    'alias': 'menú-astoria',
#    'name': 'Menú',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4C6zAjz0Wv6j8SlmJDaM5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/men%C3%BA-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 99,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7576356, 'longitude': -73.9269118},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '34-56 33rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-56 33rd St', 'Astoria, NY 11106']},
#    'phone': '+17186852566',
#    'display_phone': '(718) 685-2566',
#    'distance': 1102.9164792183465},
#   {'id': '2Pvm8P4tXH_kd1nSSe4Z0A',
#    'alias': 'dear-han-cafe-woodside',
#    'name': 'Dear Han Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wJc7auCPJs5ysKEQMUrYaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dear-han-cafe-woodside?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7452451696603,
#     'longitude': -73.9054226808178},
#    'transactions': [],
#    'location': {'address1': '59-02 Woodside Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['59-02 Woodside Ave', 'Woodside, NY 11377']},
#    'phone': '+17184249838',
#    'display_phone': '(718) 424-9838',
#    'distance': 2790.6775766002997},
#   {'id': 'vkTIiY71TC4_xUw4k7KdBA',
#    'alias': 'under-pressure-espresso-bar-astoria',
#    'name': 'Under Pressure Espresso Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ExGz3gtX9u2DU7nAfAgX9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/under-pressure-espresso-bar-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.764777, 'longitude': -73.92353},
#    'transactions': [],
#    'location': {'address1': '30-92 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-92 31st St', 'Astoria, NY 11102']},
#    'phone': '+17184339380',
#    'display_phone': '(718) 433-9380',
#    'distance': 256.9324877327024},
#   {'id': '2uS1f2hNHPzHPOLUdxrVHA',
#    'alias': 'kinship-coffee-astoria-3',
#    'name': 'Kinship Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DmFaKAqP28nSoUWTTqvjIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinship-coffee-astoria-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 198,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7634513207248,
#     'longitude': -73.9151231902811},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '30-05 Steinway St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-05 Steinway St', 'Astoria, NY 11103']},
#    'phone': '+16464687149',
#    'display_phone': '(646) 468-7149',
#    'distance': 707.7060722085931},
#   {'id': 'FSQsMolZ5SONv0I1trhvwA',
#    'alias': 'moa-coffee-astoria',
#    'name': 'Moa Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvbEIz9iI_iOvDMnkZJ-WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moa-coffee-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76243, 'longitude': -73.91258},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '43-04 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-04 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19293280043',
#    'display_phone': '(929) 328-0043',
#    'distance': 946.8500306031873},
#   {'id': 'bqf-UHIqzbSdrr7m1CsaVw',
#    'alias': 'crossbar-café-queens',
#    'name': 'Crossbar Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i6qcyxx-iWcp0hd9gLqnUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crossbar-caf%C3%A9-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7561262, 'longitude': -73.922199},
#    'transactions': [],
#    'location': {'address1': '34-23 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-23 38th St', 'Queens, NY 11101']},
#    'phone': '+16464179646',
#    'display_phone': '(646) 417-9646',
#    'distance': 1176.759350234871},
#   {'id': 'L9SKVe8qIvL_ZUrWwitdfQ',
#    'alias': 'château-le-woof-astoria-2',
#    'name': 'Château le Woof',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2QiU7ljwmtq_1sNClxlXzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A2teau-le-woof-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 97,
#    'categories': [{'alias': 'petstore', 'title': 'Pet Stores'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7691527, 'longitude': -73.9353705},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31-01 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-01 Vernon Blvd', 'Astoria, NY 11106']},
#    'phone': '+17186269663',
#    'display_phone': '(718) 626-9663',
#    'distance': 1137.7308673415139},
#   {'id': 'iuveiLDb5UMgR__GDa6_Ow',
#    'alias': 'balancero-astoria',
#    'name': 'Balancero',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Tttv3T4S3EOa21yvzk24Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balancero-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.762306, 'longitude': -73.918382},
#    'transactions': [],
#    'location': {'address1': '30-95 37th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-95 37th St', 'Astoria, NY 11103']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 602.3418722528346},
#   {'id': 'zHR6xvSiqX9UqAAaTsAoNw',
#    'alias': 'sweetleaf-coffee-long-island-city-2',
#    'name': 'Sweetleaf Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/msQnyfMPB2O4cVWhlvqyYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetleaf-coffee-long-island-city-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748429, 'longitude': -73.9383244},
#    'transactions': [],
#    'location': {'address1': '28-10 Jackson Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-10 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183618000',
#    'display_phone': '(718) 361-8000',
#    'distance': 2475.620547405862},
#   {'id': 'wlZUabctW1qOQbg-OCPhzA',
#    'alias': 'ok-cafe-astoria',
#    'name': 'OK Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JvLxloszSKdti8XK4ZmfVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ok-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 167,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7752143591642,
#     'longitude': -73.9098901301622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '22-04 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22-04 33rd St', 'Astoria, NY 11105']},
#    'phone': '+17184408789',
#    'display_phone': '(718) 440-8789',
#    'distance': 1389.778499310231},
#   {'id': 'fUuy7SqkGJPWpF5NwDklFA',
#    'alias': 'astoria-provisions-long-island-city',
#    'name': 'Astoria Provisions',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rAtxif9BmNh_eO8QVp2oCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-provisions-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 155,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722612331431,
#     'longitude': -73.9291319623589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '12-23 Astoria Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12-23 Astoria Blvd', 'Long Island City, NY 11102']},
#    'phone': '+19173964002',
#    'display_phone': '(917) 396-4002',
#    'distance': 835.5232619184637},
#   {'id': 'vrrJiOKEfCKnSOnEgagW7Q',
#    'alias': 'coffee-and-green-queens',
#    'name': 'Coffee & Green',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UiZOqq5v7bgdSW2KQJukRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-and-green-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7596849, 'longitude': -73.9367117},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2106 36th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2106 36th Ave', 'Queens, NY 11106']},
#    'phone': '+17186068414',
#    'display_phone': '(718) 606-8414',
#    'distance': 1460.6049862067885},
#   {'id': 'YI49ybEJNLBbzwl5Qx2AMg',
#    'alias': 'cafe-boulis-astoria',
#    'name': 'Cafe Boulis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mjwPnvpliSE0c9fYICM8tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-boulis-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 190,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7646102445833,
#     'longitude': -73.9236790957008},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '30-15 31st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-15 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17188061014',
#    'display_phone': '(718) 806-1014',
#    'distance': 282.49418880750454},
#   {'id': 'lm6AchFt32BqTf3OoQBBPw',
#    'alias': 'sonbobs-astoria',
#    'name': 'Sonbobs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lKAuwE8vvTmCtEtP8GyYPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sonbobs-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7673603, 'longitude': -73.917382},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '34-15 28th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-15 28th Ave', 'Astoria, NY 11103']},
#    'phone': '+13475272217',
#    'display_phone': '(347) 527-2217',
#    'distance': 429.4574593389625},
#   {'id': 'W5XLAjpyO3WscCEhARpyrQ',
#    'alias': 'biskoti-bakery-cafe-astoria',
#    'name': 'Biskoti Bakery Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wB7xkA2FOWJ6S510HfGKUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biskoti-bakery-cafe-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76413, 'longitude': -73.91606},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-20 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-20 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19292960180',
#    'display_phone': '(929) 296-0180',
#    'distance': 600.141817182123},
#   {'id': '6moXprIoZQnL82vAiCTY1Q',
#    'alias': 'coffee-pot-astoria',
#    'name': 'Coffee Pot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YyFyFnAQO5T9BFg9YwcfoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-pot-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77534, 'longitude': -73.91378},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2819 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2819 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17187261274',
#    'display_phone': '(718) 726-1274',
#    'distance': 1173.592999617699},
#   {'id': 'bvuPipiMPe5FURKZh06Zxg',
#    'alias': 'tea-and-milk-astoria',
#    'name': 'Tea and Milk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b3FHw1yZ7K5lcXp-J13Zww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-milk-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 403,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75904, 'longitude': -73.92631},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '32-02 34th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-02 34th Ave', 'Astoria, NY 11106']},
#    'phone': '+13479212056',
#    'display_phone': '(347) 921-2056',
#    'distance': 933.3178372150321},
#   {'id': 'i6tJsImlASP0mZWH3vf9uQ',
#    'alias': 'sweet-habit-astoria',
#    'name': 'Sweet Habit',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F_5nPLsO6cqBeVE2IamQpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-habit-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75707, 'longitude': -73.91439},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4511 Broadway',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4511 Broadway', 'Fl 1', 'Astoria, NY 11103']},
#    'phone': '+13475272602',
#    'display_phone': '(347) 527-2602',
#    'distance': 1273.0365322403984},
#   {'id': 'owvn3TwI2oweLWh4D7strA',
#    'alias': 'comfortland-astoria-2',
#    'name': 'Comfortland',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8M3uq_v8ug9JCQgHO1oA9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comfortland-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 141,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763751576777,
#     'longitude': -73.9145824245542},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40-09 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-09 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+16314579815',
#    'display_phone': '(631) 457-9815',
#    'distance': 729.18226925672},
#   {'id': 't01jp2WFJvAWh_TGk7Aguw',
#    'alias': 'infinitea-ny-astoria',
#    'name': 'INFINITEA NY',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qmik9UONstebmLyjX6GRAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/infinitea-ny-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 110,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77185, 'longitude': -73.9237799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2309 Astoria Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2309 Astoria Blvd', 'Astoria, NY 11102']},
#    'phone': '+17187770698',
#    'display_phone': '(718) 777-0698',
#    'distance': 561.1703055390101},
#   {'id': '_DPasRlhN-P3Y1b24NWzMA',
#    'alias': 'kinship-coffee-astoria-5',
#    'name': 'Kinship Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/o8q3cAJuM6K5qD08mC5Qmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kinship-coffee-astoria-5?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 11,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7620306, 'longitude': -73.9258523},
#    'transactions': [],
#    'location': {'address1': '30-10 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-10 Broadway', 'Astoria, NY 11106']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 621.8261073428001},
#   {'id': '7ov7U0U9UbzRjlLw7wL9bg',
#    'alias': 'the-teapsy-new-york-astoria',
#    'name': 'The Teapsy New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ikZd8vrLqUMz756M8tw1Xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-teapsy-new-york-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 142,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7658014094971,
#     'longitude': -73.9191635864046},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '33-17 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-17 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19293280090',
#    'display_phone': '(929) 328-0090',
#    'distance': 282.51173464297125},
#   {'id': 'R8OGE7C4u_22y8KL8zdHyQ',
#    'alias': 'the-mill-coffee-company-long-island-city',
#    'name': 'The Mill Coffee Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3fbZn4t8d3chrXmTJNoHUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mill-coffee-company-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7483347, 'longitude': -73.9495972},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '44-61 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44-61 11th St', 'Long Island City, NY 11101']},
#    'phone': '+17188436455',
#    'display_phone': '(718) 843-6455',
#    'distance': 3095.6810153370984},
#   {'id': 'iZ_OF8GKvBZh_fPIpwdGKw',
#    'alias': 'astoria-cafe-queens',
#    'name': 'Astoria Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mDD9ayxHy7A_oB8JJ1Hs5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-cafe-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77217, 'longitude': -73.92075},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2608 Hoyt Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2608 Hoyt Ave S', 'Queens, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 599.7193629816181},
#   {'id': 'asW_ljefQQam9zjc9ZQaMw',
#    'alias': 'oslo-coffee-roasters-new-york',
#    'name': 'Oslo Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xALfil8scd3ylUlJ50h_kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oslo-coffee-roasters-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 247,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76914, 'longitude': -73.95372},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '422 E 75th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['422 E 75th St', 'New York, NY 10021']},
#    'phone': '+17187820332',
#    'display_phone': '(718) 782-0332',
#    'distance': 2667.047334910252},
#   {'id': 'zPdIeG11UZ6TkUtBeVYkmQ',
#    'alias': 'la-barista-queens',
#    'name': 'La Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/idcgxbyRCuI1ek2H-rBV_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-barista-queens?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.767541, 'longitude': -73.923342},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2910 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2910 30th Ave', 'Queens, NY 11102']},
#    'phone': '+19294621111',
#    'display_phone': '(929) 462-1111',
#    'distance': 121.59639970281188},
#   {'id': 'Rc9_uzaTwqFTG1LGlbTPxQ',
#    'alias': 'new-york-city-bagel-and-coffee-house-astoria-2',
#    'name': 'New York City Bagel & Coffee House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8ejO2BbnrFfHbRDFavYmcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-city-bagel-and-coffee-house-astoria-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 239,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7589283752034,
#     'longitude': -73.9186164388547},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '40-05 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-05 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17187289511',
#    'display_phone': '(718) 728-9511',
#    'distance': 935.0685542769104},
#   {'id': 'mIDV-IEfeZsQtVW1BUHXLA',
#    'alias': 'indie-long-island-city',
#    'name': 'Indie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wwxPYVC7_6Ier6JB47ch8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indie-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 135,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748884, 'longitude': -73.942401},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '43-10 Crescent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-10 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+17184826954',
#    'display_phone': '(718) 482-6954',
#    'distance': 2627.6362635679043},
#   {'id': 'LjmfjBHC-dQ5ld3qq9moXw',
#    'alias': 'variety-coffee-roasters-new-york-4',
#    'name': 'Variety Coffee Roasters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jKMJicgkbGAJpjriaKn4NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/variety-coffee-roasters-new-york-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779005, 'longitude': -73.95569},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1269 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1269 Lexington Ave', 'New York, NY 10028']},
#    'phone': '+12122892104',
#    'display_phone': '(212) 289-2104',
#    'distance': 3125.7699938135524},
#   {'id': 'ydFXOSGLl-pqLXccd6qaJQ',
#    'alias': 'queens-room-astoria-3',
#    'name': "Queen's Room",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Y1IOBOh_alaAYhL5TBC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-room-astoria-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 132,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7741316, 'longitude': -73.9082624},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3602 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3602 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+13479873994',
#    'display_phone': '(347) 987-3994',
#    'distance': 1423.1279595334672},
#   {'id': 'euO-c5OpErE3UJCAliC4Bw',
#    'alias': 'mellow-yellow-new-york-3',
#    'name': 'Mellow Yellow',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gDbYdKYGj8oAetrJ2jk8Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mellow-yellow-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 280,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77929, 'longitude': -73.94785},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1729 1st Av',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1729 1st Av', 'New York, NY 10128']},
#    'phone': '+12127227220',
#    'display_phone': '(212) 722-7220',
#    'distance': 2567.232038123589},
#   {'id': 'CXgpu7gm6ofb_ldC_q9GmA',
#    'alias': 'bb-cafe-long-island-city',
#    'name': 'BB Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qYP66cSpxWypAKve3SjD2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bb-cafe-long-island-city?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7530215861517,
#     'longitude': -73.9332820102572},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3007 39th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3007 39th Ave', 'Long Island City, NY 11101']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1802.649468404453},
#   {'id': 'jeu3yDGlvY-yInrO3e2mFQ',
#    'alias': 'standard-cafe-new-york',
#    'name': 'Standard Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2I05wHNx6Inm_sYeJfv0uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/standard-cafe-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75194, 'longitude': -73.925413},
#    'transactions': [],
#    'location': {'address1': '37-18 Northern Blvd',
#     'address2': 'Ste 106',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-18 Northern Blvd',
#      'Ste 106',
#      'New York, NY 11101']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1684.170142296687},
#   {'id': 'bIhtPWm8YvcExO1ye9L0HA',
#    'alias': 'coffeed-queens-4',
#    'name': 'Coffeed',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iFzN_viGtTOvVWrrnktDXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffeed-queens-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.768133, 'longitude': -73.924766},
#    'transactions': [],
#    'location': {'address1': '25-10 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-10 30th Ave', 'Queens, NY 11102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 281.73310900358445},
#   {'id': 'MjkCDpn7zYYXj2bBP3Oadw',
#    'alias': 'black-star-bakery-and-cafe-new-york-2',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-8szCAw1IKcyj3B78y1XpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7749269639842,
#     'longitude': -73.948163241148},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1597 York Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1597 York Ave', 'New York, NY 10028']},
#    'phone': '+16467264546',
#    'display_phone': '(646) 726-4546',
#    'distance': 2362.3829003150204}],
#  'total': 1500,
#  'region': {'center': {'longitude': -73.92219543457031,
#    'latitude': 40.76688875374591}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %%
# What are the keys in this dictionary and the datatypes of their values.
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
for key in data:
    print(f'{key}\n type: {type(data[key])}')
# Out:
# businesses
#  type: <class 'list'>
# total
#  type: <class 'int'>
# region
#  type: <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
# Yelp limits results to 50, but there are 1500 total in their database

print(data['total'])
print(len(data['businesses']))
# Out:
# 1500
# 50

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
# One business
business = data['businesses'][4]

# %%
business
# Out:
# {'id': 'LdD70vbg64ufRoMOw1Kjuw',
#  'alias': 'mighty-oak-roasters-astoria',
#  'name': 'Mighty Oak Roasters',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gyk4yTqR5qs-Ql1ylvzasw/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/mighty-oak-roasters-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#  'review_count': 46,
#  'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#   {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.77358, 'longitude': -73.91675},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '28-01 24th Ave',
#   'address2': '',
#   'address3': None,
#   'city': 'Astoria',
#   'zip_code': '11102',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['28-01 24th Ave', 'Astoria, NY 11102']},
#  'phone': '+17187779663',
#  'display_phone': '(718) 777-9663',
#  'distance': 865.6108311280316}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
business_info = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['display_phone']]

# %%
business_info
# Out:
# ['Mighty Oak Roasters', '28-01 24th Ave, Astoria, NY 11102', '(718) 777-9663']

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        biz_list = [business['name'],
            ', '.join(business['location']['display_address']), 
            business['display_phone']]
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_list)

    # return the container with all of the parsed results
    return parsed_data

# %%
parse_data(data['businesses'])
# Out:
# [['Astoria Coffee', '30-04 30th St, Astoria, NY 11102', '(347) 619-3915'],
#  ['Gossip Coffee', '37-04 30th Ave, Astoria, NY 11103', '(718) 440-8792'],
#  ['Stellar Brews',
#   '32-13 Broadway Astoria, Queens, NY 11106',
#   '(646) 783-9261'],
#  ['Partners Coffee',
#   '26-25 Jackson Ave, Long Island City, NY 11101',
#   '(347) 531-0477'],
#  ['Mighty Oak Roasters',
#   '28-01 24th Ave, Astoria, NY 11102',
#   '(718) 777-9663'],
#  ['Kinship Coffee', '32-14 Steinway St, Astoria, NY 11103', ''],
#  ['Sip A Cup', '2517 30th Ave, Long Island City, NY 11102', ''],
#  ['Sweet Scene', '35-13 34th Ave, Astoria, NY 11106', '(917) 832-7443'],
#  ['Park Coffee', '26-17 23rd Ave, New York, NY 11105', ''],
#  ['Coffee Plus Cake', '25-11 Astoria Blvd, New York, NY 11102', ''],
#  ['787 Coffee', '228 E 80th St, New York, NY 10075', '(646) 850-0234'],
#  ['Madame Sousou Cafe', '31-05 33rd St, Astoria, NY 11106', '(718) 710-6577'],
#  ['Regalia Roasting Collective',
#   '3902 Crescent St, Long Island City, NY 11101',
#   '(917) 805-7442'],
#  ['Flor de Azalea Cafe', '902 34th Ave, Astoria, NY 11106', '(718) 777-0523'],
#  ['Cascara Coffee And Tea',
#   '31-19 Newtown Ave, Queens, NY 11102',
#   '(718) 606-8606'],
#  ['Menú', '34-56 33rd St, Astoria, NY 11106', '(718) 685-2566'],
#  ['Dear Han Cafe', '59-02 Woodside Ave, Woodside, NY 11377', '(718) 424-9838'],
#  ['Under Pressure Espresso Bar',
#   '30-92 31st St, Astoria, NY 11102',
#   '(718) 433-9380'],
#  ['Kinship Coffee', '30-05 Steinway St, Astoria, NY 11103', '(646) 468-7149'],
#  ['Moa Coffee', '43-04 30th Ave, Astoria, NY 11103', '(929) 328-0043'],
#  ['Crossbar Café', '34-23 38th St, Queens, NY 11101', '(646) 417-9646'],
#  ['Château le Woof', '31-01 Vernon Blvd, Astoria, NY 11106', '(718) 626-9663'],
#  ['Balancero', '30-95 37th St, Astoria, NY 11103', ''],
#  ['Sweetleaf Coffee',
#   '28-10 Jackson Ave, Long Island City, NY 11101',
#   '(718) 361-8000'],
#  ['OK Cafe', '22-04 33rd St, Astoria, NY 11105', '(718) 440-8789'],
#  ['Astoria Provisions',
#   '12-23 Astoria Blvd, Long Island City, NY 11102',
#   '(917) 396-4002'],
#  ['Coffee & Green', '2106 36th Ave, Queens, NY 11106', '(718) 606-8414'],
#  ['Cafe Boulis', '30-15 31st Ave, Astoria, NY 11106', '(718) 806-1014'],
#  ['Sonbobs', '34-15 28th Ave, Astoria, NY 11103', '(347) 527-2217'],
#  ['Biskoti Bakery Cafe',
#   '37-20 30th Ave, Astoria, NY 11103',
#   '(929) 296-0180'],
#  ['Coffee Pot', '2819 23rd Ave, Astoria, NY 11105', '(718) 726-1274'],
#  ['Tea and Milk', '32-02 34th Ave, Astoria, NY 11106', '(347) 921-2056'],
#  ['Sweet Habit', '4511 Broadway, Fl 1, Astoria, NY 11103', '(347) 527-2602'],
#  ['Comfortland', '40-09 30th Ave, Astoria, NY 11103', '(631) 457-9815'],
#  ['INFINITEA NY', '2309 Astoria Blvd, Astoria, NY 11102', '(718) 777-0698'],
#  ['Kinship Coffee', '30-10 Broadway, Astoria, NY 11106', ''],
#  ['The Teapsy New York',
#   '33-17 30th Ave, Astoria, NY 11103',
#   '(929) 328-0090'],
#  ['The Mill Coffee Company',
#   '44-61 11th St, Long Island City, NY 11101',
#   '(718) 843-6455'],
#  ['Astoria Cafe', '2608 Hoyt Ave S, Queens, NY 11102', ''],
#  ['Oslo Coffee Roasters',
#   '422 E 75th St, New York, NY 10021',
#   '(718) 782-0332'],
#  ['La Barista', '2910 30th Ave, Queens, NY 11102', '(929) 462-1111'],
#  ['New York City Bagel & Coffee House',
#   '40-05 Broadway, Astoria, NY 11103',
#   '(718) 728-9511'],
#  ['Indie', '43-10 Crescent St, Long Island City, NY 11101', '(718) 482-6954'],
#  ['Variety Coffee Roasters',
#   '1269 Lexington Ave, New York, NY 10028',
#   '(212) 289-2104'],
#  ["Queen's Room", '3602 Ditmars Blvd, Astoria, NY 11105', '(347) 987-3994'],
#  ['Mellow Yellow', '1729 1st Av, New York, NY 10128', '(212) 722-7220'],
#  ['BB Cafe', '3007 39th Ave, Long Island City, NY 11101', ''],
#  ['Standard Cafe', '37-18 Northern Blvd, Ste 106, New York, NY 11101', ''],
#  ['Coffeed', '25-10 30th Ave, Queens, NY 11102', ''],
#  ['Black Star Bakery & Cafe',
#   '1597 York Ave, New York, NY 10028',
#   '(646) 726-4546']]

# %%
import pandas as pd

columns = ['Name', 'Address', 'Phone']
df = pd.DataFrame(parse_data(data['businesses']), columns=columns)
df
# Out:
#                                   Name  \
# 0                       Astoria Coffee
# 1                        Gossip Coffee
# 2                        Stellar Brews
# 3                      Partners Coffee
# 4                  Mighty Oak Roasters
# 5                       Kinship Coffee
# 6                            Sip A Cup
# 7                          Sweet Scene
# 8                          Park Coffee
# 9                     Coffee Plus Cake
# 10                          787 Coffee
# 11                  Madame Sousou Cafe
# 12         Regalia Roasting Collective
# 13                 Flor de Azalea Cafe
# 14              Cascara Coffee And Tea
# 15                                Menú
# 16                       Dear Han Cafe
# 17         Under Pressure Espresso Bar
# 18                      Kinship Coffee
# 19                          Moa Coffee
# 20                       Crossbar Café
# 21                     Château le Woof
# 22                           Balancero
# 23                    Sweetleaf Coffee
# 24                             OK Cafe
# 25                  Astoria Provisions
# 26                      Coffee & Green
# 27                         Cafe Boulis
# 28                             Sonbobs
# 29                 Biskoti Bakery Cafe
# 30                          Coffee Pot
# 31                        Tea and Milk
# 32                         Sweet Habit
# 33                         Comfortland
# 34                        INFINITEA NY
# 35                      Kinship Coffee
# 36                 The Teapsy New York
# 37             The Mill Coffee Company
# 38                        Astoria Cafe
# 39                Oslo Coffee Roasters
# 40                          La Barista
# 41  New York City Bagel & Coffee House
# 42                               Indie
# 43             Variety Coffee Roasters
# 44                        Queen's Room
# 45                       Mellow Yellow
# 46                             BB Cafe
# 47                       Standard Cafe
# 48                             Coffeed
# 49            Black Star Bakery & Cafe
#
#                                              Address           Phone
# 0                   30-04 30th St, Astoria, NY 11102  (347) 619-3915
# 1                  37-04 30th Ave, Astoria, NY 11103  (718) 440-8792
# 2           32-13 Broadway Astoria, Queens, NY 11106  (646) 783-9261
# 3      26-25 Jackson Ave, Long Island City, NY 11101  (347) 531-0477
# 4                  28-01 24th Ave, Astoria, NY 11102  (718) 777-9663
# 5               32-14 Steinway St, Astoria, NY 11103
# 6          2517 30th Ave, Long Island City, NY 11102
# 7                  35-13 34th Ave, Astoria, NY 11106  (917) 832-7443
# 8                 26-17 23rd Ave, New York, NY 11105
# 9             25-11 Astoria Blvd, New York, NY 11102
# 10                 228 E 80th St, New York, NY 10075  (646) 850-0234
# 11                  31-05 33rd St, Astoria, NY 11106  (718) 710-6577
# 12      3902 Crescent St, Long Island City, NY 11101  (917) 805-7442
# 13                   902 34th Ave, Astoria, NY 11106  (718) 777-0523
# 14               31-19 Newtown Ave, Queens, NY 11102  (718) 606-8606
# 15                  34-56 33rd St, Astoria, NY 11106  (718) 685-2566
# 16            59-02 Woodside Ave, Woodside, NY 11377  (718) 424-9838
# 17                  30-92 31st St, Astoria, NY 11102  (718) 433-9380
# 18              30-05 Steinway St, Astoria, NY 11103  (646) 468-7149
# 19                 43-04 30th Ave, Astoria, NY 11103  (929) 328-0043
# 20                   34-23 38th St, Queens, NY 11101  (646) 417-9646
# 21              31-01 Vernon Blvd, Astoria, NY 11106  (718) 626-9663
# 22                  30-95 37th St, Astoria, NY 11103
# 23     28-10 Jackson Ave, Long Island City, NY 11101  (718) 361-8000
# 24                  22-04 33rd St, Astoria, NY 11105  (718) 440-8789
# 25    12-23 Astoria Blvd, Long Island City, NY 11102  (917) 396-4002
# 26                   2106 36th Ave, Queens, NY 11106  (718) 606-8414
# 27                 30-15 31st Ave, Astoria, NY 11106  (718) 806-1014
# 28                 34-15 28th Ave, Astoria, NY 11103  (347) 527-2217
# 29                 37-20 30th Ave, Astoria, NY 11103  (929) 296-0180
# 30                  2819 23rd Ave, Astoria, NY 11105  (718) 726-1274
# 31                 32-02 34th Ave, Astoria, NY 11106  (347) 921-2056
# 32            4511 Broadway, Fl 1, Astoria, NY 11103  (347) 527-2602
# 33                 40-09 30th Ave, Astoria, NY 11103  (631) 457-9815
# 34              2309 Astoria Blvd, Astoria, NY 11102  (718) 777-0698
# 35                 30-10 Broadway, Astoria, NY 11106
# 36                 33-17 30th Ave, Astoria, NY 11103  (929) 328-0090
# 37         44-61 11th St, Long Island City, NY 11101  (718) 843-6455
# 38                 2608 Hoyt Ave S, Queens, NY 11102
# 39                 422 E 75th St, New York, NY 10021  (718) 782-0332
# 40                   2910 30th Ave, Queens, NY 11102  (929) 462-1111
# 41                 40-05 Broadway, Astoria, NY 11103  (718) 728-9511
# 42     43-10 Crescent St, Long Island City, NY 11101  (718) 482-6954
# 43            1269 Lexington Ave, New York, NY 10028  (212) 289-2104
# 44              3602 Ditmars Blvd, Astoria, NY 11105  (347) 987-3994
# 45                   1729 1st Av, New York, NY 10128  (212) 722-7220
# 46         3007 39th Ave, Long Island City, NY 11101
# 47  37-18 Northern Blvd, Ste 106, New York, NY 11101
# 48                  25-10 30th Ave, Queens, NY 11102
# 49                 1597 York Ave, New York, NY 10028  (646) 726-4546

# %%
# Write CSV File
df.to_csv('Astoria_Coffee_Shops.csv')
